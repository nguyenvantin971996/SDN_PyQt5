# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenvantin971996/SDN_PyQt5/blob/main/ryu_controller/GA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://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@github.com/nguyenvantin971996/SDN_PyQt5.git
# Out:
# Cloning into 'SDN_PyQt5'...
# remote: Enumerating objects: 914, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 914 (delta 72), reused 63 (delta 30), pack-reused 784 (from 1)
# Receiving objects: 100% (914/914), 32.06 MiB | 9.91 MiB/s, done.
# Resolving deltas: 100% (480/480), done.

# %%
import os
os.chdir('SDN_PyQt5/ryu_controller')

import numpy as np
import time
import matplotlib.pyplot as plt
import matplotlib
font = {'size'   : 14}
matplotlib.rc('font', **font)

from GA import GA
from Yen import Yen
from get_metric import getMetric

Times = 100
src = 1
dst = 15

N = 10
Max = 100
K = 4

Pc = 0.7
Pm = [0.1, 0.7]
Ts = 2

weight_map = getMetric('../topo_mininet/15_nodes.json')
alg_yen = Yen(weight_map, src, dst, K)
paths_yen, paths_edges_yen, pw_yen = alg_yen.compute_shortest_paths()
paths_yen, paths_edges_yen, pw_yen
# Out:
# ([[1, 5, 6, 7, 15],
#   [1, 12, 13, 9, 4, 15],
#   [1, 2, 3, 4, 15],
#   [1, 12, 10, 5, 6, 7, 15]],
#  [[(1, 5), (5, 6), (6, 7), (7, 15)],
#   [(1, 12), (12, 13), (13, 9), (9, 4), (4, 15)],
#   [(1, 2), (2, 3), (3, 4), (4, 15)],
#   [(1, 12), (12, 10), (10, 5), (5, 6), (6, 7), (7, 15)]],
#  [4.5, 5.5, 8.1, 8.6])

# %%
sum(pw_yen)
# Out:
# 26.700000000000003

# %%
number_success_1 = np.zeros(K)
sum_1 = []
time_1 = []
for i in range(Times):
    paths_alg, paths_edges_alg, pw_alg, start, end = [], [], [], None, None
    alg = GA(weight_map, src, dst, K, N, Max, Pc, Pm[0], Ts)
    while len(pw_alg) != K:
        start = time.time()
        paths_alg, paths_edges_alg, pw_alg = alg.compute_shortest_paths()
        end = time.time()
    time_1.append(end - start)
    sum_1.append(sum(pw_alg))
    for j1 in range(K):
        for item in pw_alg:
            if pw_yen[j1] == item:
                pw_alg.remove(item)
                number_success_1[j1] += 1
                break

# %%
number_success_2 = np.zeros(K)
sum_2 = []
time_2 = []
for i in range(Times):
    paths_alg, paths_edges_alg, pw_alg, start, end = [], [], [], None, None
    alg = GA(weight_map, src, dst, K, N, Max, Pc, Pm[1], Ts)
    while len(pw_alg) != K:
        start = time.time()
        paths_alg, paths_edges_alg, pw_alg = alg.compute_shortest_paths()
        end = time.time()
    time_2.append(end - start)
    sum_2.append(sum(pw_alg))
    for j1 in range(K):
        for item in pw_alg:
            if pw_yen[j1] == item:
                pw_alg.remove(item)
                number_success_2[j1] += 1
                break

# %%
print(number_success_1, number_success_2)
# Out:
# [80.  9. 54. 19.] [62. 34. 65. 44.]

# %%
xticks = np.arange(K)+1
width = 0.3
fig = plt.figure(figsize=(10, 5))
plt.xticks(xticks)
yticks = (np.arange(10) + 1) * 10
plt.yticks(yticks)
plt.ylim(0, 1.3*Times)
plt.bar(xticks-0.15, number_success_1, width, color='red')
plt.bar(xticks+0.15, number_success_2, width, color='deepskyblue', hatch='\\')
plt.xlabel("Path No.")
plt.ylabel("Number of successful searches")
plt.legend(["Pm = 0.1", "Pm = 0.7"], loc="upper right")
plt.grid()
plt.savefig("GA/Pm_nss.png", dpi=200, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10, 5))

mean_1, std_1, median_1 = np.mean(sum_1), np.std(sum_1), np.median(sum_1)
mean_2, std_2, median_2 = np.mean(sum_2), np.std(sum_2), np.median(sum_2)

plt.ylim(20, 90)

plt.plot(range(1, Times+1), sum_1, label=f"Pm = 0.1 (Median = {median_1:.2f}, Mean = {mean_1:.2f}, Std = {std_1:.2f})", linewidth=3, color='red')
plt.plot(range(1, Times+1), sum_2, label=f"Pm = 0.7 (Median = {median_2:.2f}, Mean = {mean_2:.2f}, Std = {std_2:.2f})", linewidth=3, color='deepskyblue', linestyle='dashed')

plt.legend(loc="upper right")
plt.xlabel("Test No.")
plt.ylabel("Total cost of all paths")
plt.grid()
plt.savefig("GA/Pm_sum.png", dpi=200, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10, 5))

mean_1, std_1, median_1 = np.mean(time_1), np.std(time_1), np.median(time_1)
mean_2, std_2, median_2 = np.mean(time_2), np.std(time_2), np.median(time_2)

plt.ylim(0, 1.2)

plt.plot(range(1, Times+1), time_1, label=f"Pm = 0.1 (Median = {median_1:.2f}, Mean = {mean_1:.2f}, Std = {std_1:.2f})", linewidth=3, color='red')
plt.plot(range(1, Times+1), time_2, label=f"Pm = 0.7 (Median = {median_2:.2f}, Mean = {mean_2:.2f}, Std = {std_2:.2f})", linewidth=3, color='deepskyblue', linestyle='dashed')

plt.legend(loc="upper right")
plt.xlabel("Test No.")
plt.ylabel("Execution time (s)")
plt.grid()
plt.savefig("GA/Pm_time.png", dpi=200, bbox_inches='tight')

# %%
# !git add .
# !git config --global user.email "nguyenvantinrsreu@gmail.com"
# !git config --global user.name "nguyenvantin971996"
# !git commit -m "GA lam viec voi github"
# !git push origin main
# Out:
# [main a06bae7] GA lam viec voi github
#  7 files changed, 0 insertions(+), 0 deletions(-)
#  rewrite ryu_controller/GA/Pm_nss.png (98%)
#  rewrite ryu_controller/GA/Pm_sum.png (97%)
#  rewrite ryu_controller/GA/Pm_time.png (97%)
# Enumerating objects: 20, done.
# Counting objects: 100% (20/20), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (12/12), 370.25 KiB | 13.71 MiB/s, done.
# Total 12 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/nguyenvantin971996/SDN_PyQt5.git
#    ba50355..a06bae7  main -> main
