# %%
# !git clone https://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@github.com/nguyenvantin971996/SDN_PyQt5.git
# Out:
# Cloning into 'SDN_PyQt5'...
# remote: Enumerating objects: 376, done.
# remote: Counting objects: 100% (376/376), done.
# remote: Compressing objects: 100% (260/260), done.
# remote: Total 376 (delta 157), reused 325 (delta 112), pack-reused 0
# Receiving objects: 100% (376/376), 10.84 MiB | 18.66 MiB/s, done.
# Resolving deltas: 100% (157/157), done.

# %%
import os
os.chdir('SDN_PyQt5/ryu_controller')

import numpy as np
import time
import matplotlib.pyplot as plt
import matplotlib
font = {'size'   : 14}
matplotlib.rc('font', **font)

from FA_static import FA
from YenAlgorithm import YenAlgorithm
from get_metric import getMetric

Times = 100
src = 1
dst = 15

N = 10
Max = 100
K = 4

y = 1
a0 = 1
b0 = 1

weight_map = getMetric('../topo_mininet/15_nodes.json')
alg_yen = YenAlgorithm(weight_map, src, dst, K)
paths_yen, paths_edges_yen, pw_yen = alg_yen.compute_shortest_paths()
paths_yen, paths_edges_yen, pw_yen
# Out:
# ([[1, 5, 6, 7, 15],
#   [1, 12, 13, 9, 4, 15],
#   [1, 2, 3, 4, 15],
#   [1, 12, 10, 5, 6, 7, 15]],
#  [[(1, 5), (5, 6), (6, 7), (7, 15)],
#   [(1, 12), (12, 13), (13, 9), (9, 4), (4, 15)],
#   [(1, 2), (2, 3), (3, 4), (4, 15)],
#   [(1, 12), (12, 10), (10, 5), (5, 6), (6, 7), (7, 15)]],
#  [4.5, 5.5, 8.1, 8.6])

# %%
sum(pw_yen)
# Out:
# 26.700000000000003

# %%
number_success_1 = np.zeros(K)
number_success_2 = np.zeros(K)
sum_1 = []
sum_2 = []
time_1 = []
time_2 = []

# %%
number_success_1 = np.zeros(K)
sum_1 = []
time_1 = []
for i in range(Times):
    paths_alg, paths_edges_alg, pw_alg, start, end = [], [], [], None, None
    alg = FA(weight_map, src, dst, K, N, Max, y, a0, b0, modify=False)
    while len(pw_alg) != K:
        start = time.time()
        paths_alg, paths_edges_alg, pw_alg = alg.compute_shortest_paths()
        end = time.time()
    time_1.append(end - start)
    sum_1.append(sum(pw_alg))
    for j1 in range(K):
        for item in pw_alg:
            if pw_yen[j1] == item:
                pw_alg.remove(item)
                number_success_1[j1] += 1
                break

# %%
number_success_2 = np.zeros(K)
sum_2 = []
time_2 = []
for i in range(Times):
    paths_alg, paths_edges_alg, pw_alg, start, end = [], [], [], None, None
    alg = FA(weight_map, src, dst, K, N, Max, y, a0, b0, modify=True)
    while len(pw_alg) != K:
        start = time.time()
        paths_alg, paths_edges_alg, pw_alg = alg.compute_shortest_paths()
        end = time.time()
    time_2.append(end - start)
    sum_2.append(sum(pw_alg))
    for j1 in range(K):
        for item in pw_alg:
            if pw_yen[j1] == item:
                pw_alg.remove(item)
                number_success_2[j1] += 1
                break

# %%
print(number_success_1, number_success_2)
# Out:
# [100.  54.  94.  72.] [100. 100. 100. 100.]

# %%
x = np.arange(K)+1
width = 0.3
fig = plt.figure(figsize=(10, 5))
plt.xticks(x)
plt.ylim(0, 1.3*Times)
plt.bar(x-0.15, number_success_1, width, color='red')
plt.bar(x+0.15, number_success_2, width, color='deepskyblue', hatch='\\')
plt.xlabel("Path No.")
plt.ylabel("Number of successful searches")
plt.legend(["FA", "EFA"], loc="upper right")
plt.grid()
plt.savefig("FA/FA_nss.png", dpi=200, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10, 5))

mean_1, std_1 = np.mean(sum_1), np.std(sum_1)
mean_2, std_2 = np.mean(sum_2), np.std(sum_2)

plt.ylim(0.9*min(sum_1+sum_2), 1.1*max(sum_1+sum_2))

plt.plot(sum_1, label=f"FA (Mean = {mean_1:.1f}, Std = {std_1:.1f})", linewidth=3, color='red')
plt.plot(sum_2, label=f"EFA (Mean = {mean_2:.1f}, Std = {std_2:.1f})", linewidth=3, color='deepskyblue', linestyle='dashed')

plt.legend(loc="upper right")
plt.xlabel("Test No.")
plt.ylabel("Total cost of all paths")
plt.grid()
plt.savefig("FA/FA_sum.png", dpi=200, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10, 5))

mean_1, std_1 = np.mean(time_1), np.std(time_1)
mean_2, std_2 = np.mean(time_2), np.std(time_2)

plt.ylim(0.8*min(time_1+time_2), 1.2*max(time_1+time_2))

plt.plot(time_1, label=f"FA (Mean = {mean_1:.2f}, Std = {std_1:.2f})", linewidth=3, color='red')
plt.plot(time_2, label=f"EFA (Mean = {mean_2:.2f}, Std = {std_2:.2f})", linewidth=3, color='deepskyblue', linestyle='dashed')

plt.legend(loc="upper right")
plt.xlabel("Test No.")
plt.ylabel("Execution time (s)")
plt.grid()
plt.savefig("FA/FA_time.png", dpi=200, bbox_inches='tight')

# %%
# !git add .
# !git config --global user.email "nguyenvantinrsreu@gmail.com"
# !git config --global user.name "nguyenvantin971996"
# !git commit -m "FA lam viec voi github"
# !git push origin main
# Out:
# [main 122228e] FA lam viec voi github
#  7 files changed, 0 insertions(+), 0 deletions(-)
#  rewrite ryu_controller/FA/FA_nss.png (66%)
#  rewrite ryu_controller/FA/FA_sum.png (98%)
#  rewrite ryu_controller/FA/FA_time.png (98%)
# Enumerating objects: 20, done.
# Counting objects: 100% (20/20), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (12/12), 257.60 KiB | 13.56 MiB/s, done.
# Total 12 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/nguyenvantin971996/SDN_PyQt5.git
#    9e84f0d..122228e  main -> main
